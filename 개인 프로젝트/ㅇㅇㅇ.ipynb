# %%
import datetime
import getpass
class Start:
    def __init__(self):
        print("프로그램이 실행 되었습니다.")
        print("*"*50)
    def login(self):
        while True:
            print("*"*50)
            p = input("1. 로그인, 2. 회원가입, 3. 종료 : ")
            print("*"*50)
            p_data = {}
            umm = []
            if p == '1' or p == '로그인' : # 로그인 프로세스 시작
                p_id = input("사용자 ID : ")
                p_pw = getpass.getpass("사용자 PW : ")
                with open('logdata.txt','a') as f: #로그데이터에 행위 기록
                    f.write("logdata = {}  로그인 시도 ID = {}\n".format(datetime.datetime.now(),p_id))
                with open('memberdata.txt','r') as f: #회원데이터에 있는지 확인
                    data = f.read()
                    data = data.strip().replace('\n','/').replace(' ','')
                    da = data.split('/')
                    w = str(da[1])
                    e = w.split(':')
                    e1 = str(e[1])
                    k = str(da[2])
                    j= k.split(':')
                    j1 = str(j[1])
                    
                    if p_id == e1 and p_pw == j1:
                        print('{}님 환영합니다'.format(e1))
                    else:
                        print("아이디 패스워드를 확인해주세요")
                
            elif p == '2' or p == '회원가입' : # 회원 가입 프로세스 시작
                while True:
                    p_id = input("사용자 ID : ")
                    if p_id == p_data:
                        print("이미 사용하고 있는 ID 입니다.")
                    else:
                        print("사용 할 수 있는 ID 입니다")
                        p_pw = getpass.getpass("사용자 PW : ")
                        with open('memberdata.txt','a') as f:
                            f.write("{} / ID : {} / PW : {}/".format(datetime.datetime.now(),p_id, p_pw))
                        with open('logdata.txt','a') as f:
                            f.write("logdata = {}  회원가입 ID = {}\n".format(datetime.datetime.now(),p_id))
                        print("회원가입이 완료 되었습니다")
                        break
                    
            elif p == '3' or p == '종료': # 종료
                print("프로그램을 종료합니다")
                print("*"*50)
                break
            elif p == '바보':    
                print("빈정상해서 종료합니다")
                print("*"*50)
                break
            else:
                print("메뉴 중 하나를 골라주세요")
    
    def wow(self):
        print("도움말 및 명령어 : help")
        print("*"*50)
        
        while True:
            print("="*50)
            wow_a = input("명령어를 입력하세요. : ")
            print("="*50)
            if wow_a == 'help':
                print("게시물 작성 = New\n게시물 삭제 = Del (enter->) 게시물 번호\n게시물 이동 = Move (enter->) 게시물 번호\n게시물 추천 = Recommand (enter->) 추천 or 비추천 입력\n로그아웃 = Logout\n회원탈퇴 = Delid")
            elif wow_a == 'New' or wow_a == 'new' or wow_a == '작성':
                print("게시물을 작성합니다")
                title = input('게시물의 제목을 입력해주세요 : ')
                text = input('게시물의 내용을 입력해주세요 : ')
                filename = 'datafile/%s.txt' %title
                with open(filename,'a')as f:
                    f.write('{}'.format(text))
            elif wow_a == 'DelNumber' or wow_a == 'delnumber'or wow_a == '삭제':
                print("게시물을 삭제합니다")    
            elif wow_a == 'Move'or wow_a == 'move'or wow_a == '이동':
                print("게시물로 이동합니다")
            elif wow_a == 'Recommand'or wow_a == 'recommand'or wow_a == '평가':
                print("게시물을 평가합니다")
            elif wow_a == 'Logout'or wow_a == 'logout'or wow_a == '로그아웃':
                print("로그아웃 합니다")
                break
            elif wow_a == 'Delid' or wow_a == 'delid' or wow_a == '회원탈퇴':
                print("회원탈퇴를 진행합니다")
                real = input("정말 회원탈퇴를 진행하시겠습니까? : ")
                if real == 'yes' or real == '네':
                    print("회원탈퇴가 완료되었습니다")
                else:
                    print("초기 화면으로 돌아갑니다")
            else:
                print("명령어가 올바르지 않습니다")

# %%
start = Start()
start.login()
start.wow()
# Out:
# 프로그램이 실행 되었습니다.
# **************************************************
# **************************************************
# 1. 로그인, 2. 회원가입, 3. 종료 : 3
# **************************************************
# 프로그램을 종료합니다
# **************************************************
# 도움말 및 명령어 : help
# **************************************************
# ...
# 명령어를 입력하세요. : 작성
# ...
# 게시물을 작성합니다
# 게시물의 제목을 입력해주세요 : 오늘은 로그인 데이터 저장 프로세스를 만들자
# 게시물의 내용을 입력해주세요 : 제발 한 번에 되면 좋겠다
# ...

# %%
with open('memberdata.txt','r') as f: #회원데이터에 있는지 확인
    data = f.read()
    data = str(data)
    data1 =data.split('/')
    data1 =str(data1)
    data2 = data.replace('\n','/')
    data3 =data2.split('/')
    print(data3)
# Out:
# ['2021-06-30 14:51:14.566562 ', ' ID : 김땡땡 ', ' PW : 156156', '2021-06-30 14:53:59.357953 ', ' ID : 김땡땡 ', ' PW : 156156', '2021-06-30 17:26:38.293600 ', ' ID : 김인직 ', ' PW : 159159', '']

# %%
################### 사용자 database 에 추가하기 함수(회원가입) ###################

# 추가하는 방식은    email   password   wanttags  sentvideo
import pyrebase
def useradd():
    config = {
        'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
        'authDomain': "studygroup-playllist.firebaseapp.com",
        'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
        'projectId': "studygroup-playllist",
        'storageBucket': "studygroup-playllist.appspot.com",
        'messagingSenderId': "181894569806",
        'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
        'measurementId': "G-HC5K5C0C2D"
      };

    firebase = pyrebase.initialize_app(config)
    database = firebase.database()

    # 다음 사용자가 부여받을 ID 고유번호  
    userID=database.child("users_nextID").get().val()
    try:
        emailexisting=[]
        for i in range(1,userID):
            emailexisting.append(database.child('users').child(i).child('email').get().val())
    except:
        userID=1
    
            
    # 존재하는 이미 database에 존재하는 email 불러오기

    print("정보를 잘못 입력시, 'Name :' 나올때까지 enter 입력")
    while 1:
        name = input("Name : ")
        
        
        while 1:
            email = input("ID : ")
            if email in emailexisting:
                print("이미 존재하는 아이디입니다. 이메일을 다시 입력해주세요.")
            else:
                break
        
        pw = input("Password : ")
        
        if email=='' or pw=='':
            print("요구하는 정보를 다 입력해주세요.")
        else:
            break
    
    
    while 1:
        ### 나중에 업데이트 : database 확인해서 존재하는 모든 tags 고를 수 있게 만들기
        tags = input("관심있는 category를 골라주세요. (최소1개)\n1) 'python'\n2) 'crawling'\n3) 'selenium'\n4) 'pandas'\n5) 'dataframe'\n6) 'machinelearning'\n7) 'requests'\n\n입력예시 -> 1342   >"  )
        tagslists=["python",'crawling','selenium','pandas','dataframe','machinelearning','requests']
        tagsindexlist = list(set(list(tags)))

        tagschoice=[]
        for index in tagsindexlist:
            
            # try 는 혹시나 index 밖의 값입력시
            try:
                index=int(index)
                if index-1<0:
                    int('error')
                tagschoice.append(tagslists[index-1])
            except:
                print('1부터 7 숫자 조합을 제외한 숫자는 제외합니다.')
        
        if tagschoice!=[]:
            tagstr=''
            for i in tagschoice:
                tagstr+=i+', '
            print(f"{tagstr}를 관심 category로 지정합니다.")
            ## 나중에 category 수정하는 것도 만들기. 앱에서 로그인후 프로필 수정 페이지 만들기
            break
        else:
            pass
    
    userinfo = {'userID':userID,'userName':name,"email":email,"pw":pw,"tags":tagschoice}
    
    config = {
        'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
        'authDomain': "studygroup-playllist.firebaseapp.com",
        'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
        'projectId': "studygroup-playllist",
        'storageBucket': "studygroup-playllist.appspot.com",
        'messagingSenderId': "181894569806",
        'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
        'measurementId': "G-HC5K5C0C2D"
      };


    firebase = pyrebase.initialize_app(config)
    database = firebase.database()

    database.child("users").child(userID).set(userinfo)
    database.child("users_nextID").set(userID+1)
    print("Database에 추가완료")
### login 되면 


def login(checkID , checkpw):
    config = {
        'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
        'authDomain': "studygroup-playllist.firebaseapp.com",
        'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
        'projectId': "studygroup-playllist",
        'storageBucket': "studygroup-playllist.appspot.com",
        'messagingSenderId': "181894569806",
        'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
        'measurementId': "G-HC5K5C0C2D"
      };

    firebase = pyrebase.initialize_app(config)
    database = firebase.database()

    users=database.child("users").get().val()
#     userlist.remove(None)
    userlist=users[1:]
    for i in userlist:
        ID=i['email']
        pw = i['pw']
        if ID==checkID:
            if checkpw==pw:
                return True
            else:
                pass
        else:
            pass
    return False

################### 사용자 database 에 추가하기 함수(회원가입) ###################

# 추가하는 방식은    email   password   wanttags  sentvideo
import pyrebase
def useradd():
    config = {
        'apiKey': "AIzaSyBh3PyZNCdyd2mh12YcXe8Af7m6rl4QzSs",
        'authDomain': "studygroup-playllist.firebaseapp.com",
        'databaseURL': "https://studygroup-playllist-default-rtdb.firebaseio.com",
        'projectId': "studygroup-playllist",
        'storageBucket': "studygroup-playllist.appspot.com",
        'messagingSenderId': "181894569806",
        'appId': "1:181894569806:web:917dea0dd0859dd764c81f",
        'measurementId': "G-HC5K5C0C2D"
      }

    firebase = pyrebase.initialize_app(config)
    database = firebase.database()

    # 다음 사용자가 부여받을 ID 고유번호  
    userID=database.child("users_nextID").get().val()
    try:
        emailexisting=[]
        for i in range(1,userID):
            emailexisting.append(database.child('users').child(i).child('email').get().val())
    except:
        userID=1

while 1:
    ID = input("Login ID  > ")
    pw = input("Login Password  > ")
    check=login(ID,pw)
    if check==False:
        print("< 로그인 실패 >")
        addcheck=input("1) 다시 로그인 시도\n2) 회원가입\n3) 종료\n > ")
        if addcheck=='1':
            pass
        elif addcheck=='2':
            useradd()
        else:
            break
            
        
        pass
    else:
        print('< 로그인 되었습니다 >')
        break
# Out:
# < 로그인 실패 >
# < 로그인 실패 >
# < 로그인 실패 >
# < 로그인 실패 >
